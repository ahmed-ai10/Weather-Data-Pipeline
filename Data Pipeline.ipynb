# %%
import pandas as pd
import requests
from sqlalchemy import create_engine

url='https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&past_days=10&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m'
response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
response.headers["content-type"]
# Out:
# 'application/json; charset=utf-8'

# %%
data=response.json()
data
# Out:
# {'latitude': 52.52,
#  'longitude': 13.419998,
#  'generationtime_ms': 3.0955076217651367,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 38.0,
#  'hourly_units': {'time': 'iso8601',
#   'temperature_2m': '°C',
#   'relative_humidity_2m': '%',
#   'wind_speed_10m': 'km/h'},
#  'hourly': {'time': ['2026-08-30T00:00',
#    '2026-08-30T01:00',
#    '2026-08-30T02:00',
#    '2026-08-30T03:00',
#    '2026-08-30T04:00',
#    '2026-08-30T05:00',
#    '2026-08-30T06:00',
#    '2026-08-30T07:00',
#    '2026-08-30T08:00',
#    '2026-08-30T09:00',
#    '2026-08-30T10:00',
#    '2026-08-30T11:00',
#    '2026-08-30T12:00',
#    '2026-08-30T13:00',
#    '2026-08-30T14:00',
#    '2026-08-30T15:00',
#    '2026-08-30T16:00',
#    '2026-08-30T17:00',
#    '2026-08-30T18:00',
#    '2026-08-30T19:00',
#    '2026-08-30T20:00',
#    '2026-08-30T21:00',
#    '2026-08-30T22:00',
#    '2026-08-30T23:00',
#    '2026-08-31T00:00',
#    '2026-08-31T01:00',
# ...

# %%
df=pd.DataFrame(data)
df.head(10)
# Out:
#                       latitude  longitude  generationtime_ms  \
# time                     52.52  13.419998           3.095508
# temperature_2m           52.52  13.419998           3.095508
# relative_humidity_2m     52.52  13.419998           3.095508
# wind_speed_10m           52.52  13.419998           3.095508
#
#                       utc_offset_seconds timezone timezone_abbreviation  \
# time                                   0      GMT                   GMT
# temperature_2m                         0      GMT                   GMT
# relative_humidity_2m                   0      GMT                   GMT
# wind_speed_10m                         0      GMT                   GMT
#
#                       elevation hourly_units  \
# time                       38.0      iso8601
# temperature_2m             38.0           °C
# relative_humidity_2m       38.0            %
# wind_speed_10m             38.0         km/h
#
# ...

# %%
df = pd.DataFrame(data["hourly"])

# %%
df["latitude"] = data["latitude"]
df["longitude"] = data["longitude"]
df["elevation"] = data["elevation"]
df["timezone"] = data["timezone"]
df["timezone_abbreviation"] = data["timezone_abbreviation"]

# %%
df["time"] = pd.to_datetime(df["time"])

# %%
units = data["hourly_units"]

# %%
#Actual data
df
# Out:
#                    time  temperature_2m  relative_humidity_2m  wind_speed_10m  \
# 0   2026-08-30 00:00:00            20.0                    59             9.0
# 1   2026-08-30 01:00:00            19.8                    62             9.0
# 2   2026-08-30 02:00:00            19.5                    64            11.4
# 3   2026-08-30 03:00:00            19.3                    68            10.4
# 4   2026-08-30 04:00:00            19.3                    70            10.0
# ..                  ...             ...                   ...             ...
# 403 2026-09-15 19:00:00            20.3                    81            11.3
# 404 2026-09-15 20:00:00            19.2                    85            10.1
# 405 2026-09-15 21:00:00            18.1                    87            10.9
# 406 2026-09-15 22:00:00            17.1                    86            11.5
# 407 2026-09-15 23:00:00            16.2                    84            11.4
#
# ...

# %%
# meta data
units
# Out:
# {'time': 'iso8601',
#  'temperature_2m': '°C',
#  'relative_humidity_2m': '%',
#  'wind_speed_10m': 'km/h'}

# %%
#Validation
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   408 non-null    datetime64[us]
#  1   temperature_2m         408 non-null    float64
#  2   relative_humidity_2m   408 non-null    int64
#  3   wind_speed_10m         408 non-null    float64
#  4   latitude               408 non-null    float64
#  5   longitude              408 non-null    float64
#  6   elevation              408 non-null    float64
#  7   timezone               408 non-null    str
#  8   timezone_abbreviation  408 non-null    str
# dtypes: datetime64[us](1), float64(5), int64(1), str(2)
# memory usage: 28.8 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                       time  temperature_2m  relative_humidity_2m  \
# count                  408      408.000000            408.000000
# mean   2026-09-07 11:30:00       18.360784             67.360294
# min    2026-08-30 00:00:00       12.200000             34.000000
# 25%    2026-09-03 05:45:00       16.100000             57.000000
# 50%    2026-09-07 11:30:00       17.950000             70.000000
# 75%    2026-09-11 17:15:00       20.500000             78.000000
# max    2026-09-15 23:00:00       28.500000             94.000000
# std                    NaN        3.224992             14.615467
#
#        wind_speed_10m      latitude     longitude  elevation
# count      408.000000  4.080000e+02  4.080000e+02      408.0
# mean         9.910049  5.252000e+01  1.342000e+01       38.0
# min          0.500000  5.252000e+01  1.342000e+01       38.0
# 25%          5.800000  5.252000e+01  1.342000e+01       38.0
# 50%          9.300000  5.252000e+01  1.342000e+01       38.0
# ...

# %%
df.columns
# Out:
# Index(['time', 'temperature_2m', 'relative_humidity_2m', 'wind_speed_10m',
#        'latitude', 'longitude', 'elevation', 'timezone',
#        'timezone_abbreviation'],
#       dtype='str')

# %%
df.dtypes
# Out:
# time                     datetime64[us]
# temperature_2m                  float64
# relative_humidity_2m              int64
# wind_speed_10m                  float64
# latitude                        float64
# longitude                       float64
# elevation                       float64
# timezone                            str
# timezone_abbreviation               str
# dtype: object

# %%
df.to_csv('weather_data.csv')

# %%
#load into PostagresSQL DB

# %%
engine=create_engine(
    "postgresql+psycopg2://postgres:root@localhost:5432/Weather"
    )
df2 = pd.read_csv("weather_data.csv")

# %%
df2.to_sql(
    "weather_data",
    engine,
    if_exists="append",
    index=False
    )
# Out:
# 408
